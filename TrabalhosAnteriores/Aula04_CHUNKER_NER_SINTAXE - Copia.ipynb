# %% [markdown]
# <img style="float: right;" src="fig/unifor.jpg" width="150px">
# Mineração de textos e da Web
# Profa. Vládia Pinheiro<br>
# Programa de Pós-Graduação em Informática Aplicada - PPGIA<br>
# Universidade de Fortaleza

# %% [markdown]
# # Aula 04 - Análise Sintática e Chunking
#
# ## 1. Chunking

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer 
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
from nltk.chunk.regexp import ChunkString, ChunkRule, ChinkRule 
from nltk.tree import Tree 
from nltk.chunk import RegexpChunkParser 

texto1 = "@USER Canada doesn’t need another CUCK! We already have enough #LooneyLeft #Liberals f**king up our great country!!! #Qproofs #TrudeauMustGo"
texto2 = "@USER @USER go home you’re drunk @USER #MAGA #Trump2020 👊🇺🇸👊 URL !!!"
texto = "European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices"

print(' ')
print('------- PRE-PROCESSAMENTO DE SENTENÇAS -------\n')

def preprocess(sent):
    #sent = word_tokenize(sent)
    tweet_tokenizer = TweetTokenizer()
    sent = tweet_tokenizer.tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

print(' ')
print('------- SENTENÇA PRE-PROCESSADA -------\n')
sent = preprocess(texto)
print(sent)
print("\n")

#criando um padrão para chunks
pattern = 'NP: {<DT>?<JJ>*<NN>}'
pattern1 = 'NP: {<DT>?<JJ>*<NN.*>*}'  # NN, NNS, NNP, NNPS
#pattern2 = 'NP: {<DT><NN.*><.*>*<NN.*>}'

#('the', 'DT'), ('beautiful', 'JJ'),('mobile', 'JJ'), ('phone', 'NN')  => pattern ok  / pattern1 ok
#('the', 'DT'), ('mobile', 'JJ'), ('Iphone', 'NNP') => pattern NOK / pattern1 ok
#('the', 'DT'), ('mobile', 'JJ') => pattern NOK / pattern1 ok


print(' ')
print('------- CHUNKING (em Flat Structure) PATTERN-------\n')
print(pattern)
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)

print(cs)
print("\n")

print('------- CHUNKING (em Flat Structure) PATTERN #1-------\n')
print(pattern1)
cp = nltk.RegexpParser(pattern1)
cs = cp.parse(sent)

print(cs)
print("\n")

print(' ')
print('------- CHUNKING (em IOB format) -------\n')
#IOB tags tem sido usadas para representar a estrutura de chunks
#I-inside O-outside B-beginning (B é usado somente quando existem tags seguidas de mesmo tipo, sem O tokens entre elas.)

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)


# ChunkString() inicia com uma flat tree 
#tree = Tree('S', [('the', 'DT'), ('book', 'NN'),('has', 'VBZ'), ('many', 'JJ'), ('chapters', 'NNS')]) 
print(' ')
print('------- CHUNKING / CHINKING RULES -------\n')
tree = Tree('S', sent)
print(sent)
print("\n")
print("\n")

# Inicializando ChunkString() 
chunk_string = ChunkString(tree) 
print ("Chunk String : ", chunk_string) 
  
# Inicializando ChunkRule 
chunk_rule = ChunkRule('<DT>?<JJ>*<NN.*><.*>*<NN.*>', 'chunk determinantes, adjetivos e nomes') 
chunk_rule.apply(chunk_string) 
print ("\nApplied ChunkRule : ", chunk_string) 
  
# Criando uma ChinkRule 
chink_rule = ChinkRule('<VB.*>', 'chink verbs') 
chink_rule.apply(chunk_string) 
print ("\nApplied ChinkRule : ", chunk_string, "\n")
# Out:
#
# ------- PRE-PROCESSAMENTO DE SENTENÇAS -------
#
#
# ------- SENTENÇA PRE-PROCESSADA -------
#
# [('European', 'JJ'), ('authorities', 'NNS'), ('fined', 'VBD'), ('Google', 'NNP'), ('a', 'DT'), ('record', 'NN'), ('$', '$'), ('5.1', 'CD'), ('billion', 'CD'), ('on', 'IN'), ('Wednesday', 'NNP'), ('for', 'IN'), ('abusing', 'VBG'), ('its', 'PRP$'), ('power', 'NN'), ('in', 'IN'), ('the', 'DT'), ('mobile', 'JJ'), ('phone', 'NN'), ('market', 'NN'), ('and', 'CC'), ('ordered', 'VBD'), ('the', 'DT'), ('company', 'NN'), ('to', 'TO'), ('alter', 'VB'), ('its', 'PRP$'), ('practices', 'NNS')]
#
#
#
# ------- CHUNKING (em Flat Structure) PATTERN-------
#
# NP: {<DT>?<JJ>*<NN>}
# (S
#   European/JJ
#   authorities/NNS
#   fined/VBD
#   Google/NNP
#   (NP a/DT record/NN)
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   (NP power/NN)
#   in/IN
#   (NP the/DT mobile/JJ phone/NN)
#   (NP market/NN)
#   and/CC
#   ordered/VBD
#   (NP the/DT company/NN)
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS)
#
#
# ------- CHUNKING (em Flat Structure) PATTERN #1-------
#
# NP: {<DT>?<JJ>*<NN.*>*}
# (S
#   (NP European/JJ authorities/NNS)
#   fined/VBD
#   (NP Google/NNP)
#   (NP a/DT record/NN)
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   (NP Wednesday/NNP)
#   for/IN
#   abusing/VBG
#   its/PRP$
#   (NP power/NN)
#   in/IN
#   (NP the/DT mobile/JJ phone/NN market/NN)
#   and/CC
#   ordered/VBD
#   (NP the/DT company/NN)
#   to/TO
#   alter/VB
#   its/PRP$
#   (NP practices/NNS))
#
#
#
# ------- CHUNKING (em IOB format) -------
#
# [('European', 'JJ', 'B-NP'),
#  ('authorities', 'NNS', 'I-NP'),
#  ('fined', 'VBD', 'O'),
#  ('Google', 'NNP', 'B-NP'),
#  ('a', 'DT', 'B-NP'),
#  ('record', 'NN', 'I-NP'),
#  ('$', '$', 'O'),
#  ('5.1', 'CD', 'O'),
#  ('billion', 'CD', 'O'),
#  ('on', 'IN', 'O'),
#  ('Wednesday', 'NNP', 'B-NP'),
#  ('for', 'IN', 'O'),
#  ('abusing', 'VBG', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('power', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('mobile', 'JJ', 'I-NP'),
#  ('phone', 'NN', 'I-NP'),
#  ('market', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('ordered', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('company', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('alter', 'VB', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('practices', 'NNS', 'B-NP')]
#
# ------- CHUNKING / CHINKING RULES -------
#
# [('European', 'JJ'), ('authorities', 'NNS'), ('fined', 'VBD'), ('Google', 'NNP'), ('a', 'DT'), ('record', 'NN'), ('$', '$'), ('5.1', 'CD'), ('billion', 'CD'), ('on', 'IN'), ('Wednesday', 'NNP'), ('for', 'IN'), ('abusing', 'VBG'), ('its', 'PRP$'), ('power', 'NN'), ('in', 'IN'), ('the', 'DT'), ('mobile', 'JJ'), ('phone', 'NN'), ('market', 'NN'), ('and', 'CC'), ('ordered', 'VBD'), ('the', 'DT'), ('company', 'NN'), ('to', 'TO'), ('alter', 'VB'), ('its', 'PRP$'), ('practices', 'NNS')]
#
#
#
#
# Chunk String :   <JJ>  <NNS>  <VBD>  <NNP>  <DT>  <NN>  <$>  <CD>  <CD>  <IN>  <NNP>  <IN>  <VBG>  <PRP$>  <NN>  <IN>  <DT>  <JJ>  <NN>  <NN>  <CC>  <VBD>  <DT>  <NN>  <TO>  <VB>  <PRP$>  <NNS>
#
# Applied ChunkRule :  {<JJ>  <NNS>  <VBD>  <NNP>  <DT>  <NN>  <$>  <CD>  <CD>  <IN>  <NNP>  <IN>  <VBG>  <PRP$>  <NN>  <IN>  <DT>  <JJ>  <NN>  <NN>  <CC>  <VBD>  <DT>  <NN>  <TO>  <VB>  <PRP$>  <NNS>}
#
# Applied ChinkRule :  {<JJ>  <NNS>} <VBD> {<NNP>  <DT>  <NN>  <$>  <CD>  <CD>  <IN>  <NNP>  <IN>} <VBG> {<PRP$>  <NN>  <IN>  <DT>  <JJ>  <NN>  <NN>  <CC>} <VBD> {<DT>  <NN>  <TO>} <VB> {<PRP$>  <NNS>}
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/vladiapinheiro/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/vladiapinheiro/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## 2. Reconhecimento de Entidades Mencionadas (REM) ou Named-Entity Recognition (NER)
#
# ## 2.1. NER usando pacote NLTK - PERSON, GPE e ORGANIZATION

# %%
print(' ')
print('------- EXEMPLOS DE NER COM NLTK -------\n')

# NER na sentenca "European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices"
ne_tree = nltk.ne_chunk(sent)
print(ne_tree)
print(type(ne_tree))
print("\n")

# NER na sentenca = "Mark and John S. Marchall are working at Google."
sentence = "Mark and John S. Marchall are working at Google."
ne_tree = nltk.ne_chunk(pos_tag(word_tokenize(sentence)))
print(ne_tree)
print("\n")

iob_tagged = tree2conlltags(ne_tree)
pprint(iob_tagged)
# Out:
#
# ------- EXEMPLOS DE NER COM NLTK -------
#
# (S
#   (GPE European/JJ)
#   authorities/NNS
#   fined/VBD
#   (PERSON Google/NNP)
#   a/DT
#   record/NN
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   power/NN
#   in/IN
#   the/DT
#   mobile/JJ
#   phone/NN
#   market/NN
#   and/CC
#   ordered/VBD
#   the/DT
#   company/NN
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS)
# <class 'nltk.tree.Tree'>
#
#
# (S
#   (PERSON Mark/NNP)
#   and/CC
#   (PERSON John/NNP S./NNP Marchall/NNP)
#   are/VBP
#   working/VBG
#   at/IN
#   (ORGANIZATION Google/NNP)
#   ./.)
#
#
# [('Mark', 'NNP', 'B-PERSON'),
#  ('and', 'CC', 'O'),
#  ('John', 'NNP', 'B-PERSON'),
#  ('S.', 'NNP', 'I-PERSON'),
#  ('Marchall', 'NNP', 'I-PERSON'),
#  ('are', 'VBP', 'O'),
#  ('working', 'VBG', 'O'),
#  ('at', 'IN', 'O'),
#  ('Google', 'NNP', 'B-ORGANIZATION'),
#  ('.', '.', 'O')]

# %% [markdown]
# ## 2.2 NER usando pacote SpaCy

# %%
import spacy 
#!python -m spacy download en_core_web_sm
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

print(' ')
print('------- EXEMPLOS DE NER COM SpaCy -------\n')
  
sentence = "Apple is looking at buying U.K. startup for $1 billion"
doc = nlp(sentence) 
print(type(doc))

print("Sentença: "+sentence)
print("\nEntidades e Tipos:")

for ent in doc.ents: 
    print(ent.text, ent.start_char, ent.end_char, ent.label_) 
print("\n")

sentence = "European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practice"    
doc = nlp(sentence)
print("Sentença: "+sentence)
print("\nEntidades e Tipos:")
pprint([(X.text, X.label_) for X in doc.ents])
print("\n")

# Impressão de entidades no formato IOB
# "B" means the token begins an entity, 
# "I" means it is inside an entity, 
# "O" means it is outside an entity, and 
# "" means no entity tag is set.
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
#
# ------- EXEMPLOS DE NER COM SpaCy -------
#
# <class 'spacy.tokens.doc.Doc'>
# Sentença: Apple is looking at buying U.K. startup for $1 billion
#
# Entidades e Tipos:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY
#
#
# Sentença: European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practice
#
# Entidades e Tipos:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('$5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]
#
#
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'O', ''),
#  (record, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practice, 'O', '')]

# %% [markdown]
# ## 2.3 Manipulando Entidades com SpaCy

# %%
texto_artigo="""Peter Strzok, the F.B.I. senior counterintelligence agent who disparaged President Trump in inflammatory
text messages and helped oversee the Hillary Clinton email and Russia investigations, has been fired for violating 
bureau policies, Mr. Strzok’s lawyer said Monday. Mr. Trump and his allies seized on the texts, exchanged during 
the 2016 campaign with a former F.B.I. lawyer, Lisa Page, in assailing the Russia investigation as an illegitimate 'witch hunt.'
Mr. Strzok, who rose over 20 years at the F.B.I. to become one of its most experienced counterintelligence agents,
was a key figure in the early months of the inquiry. Along with writing the texts, Mr. Strzok was accused of sending 
a highly sensitive search warrant to his personal email account. The F.B.I. had been under immense political pressure 
by Mr. Trump to dismiss Mr. Strzok, who was removed last summer from the staff of the special counsel, Robert S. Mueller III. 
The president has repeatedly denounced Mr. Strzok in posts on Twitter, and on Monday expressed satisfaction that he had been sacked."""

print(' ')
print('------- TEXTO LONGO -------\n')
print(texto_artigo)
print("\n")

article = nlp(texto_artigo)
print("No. Entidades= "+str(len(article.ents)))
print("\n")

print(' ')
print('------- Contagem de Entidades por LABEL -------\n')
labels = [x.label_ for x in article.ents]
contagem_labels=Counter(labels)
print(contagem_labels)
print("\n")

print(' ')
print('------- TOP 3 Entidades -------\n')
items = [x.text for x in article.ents]
contagem_entidades=Counter(items).most_common(3)
print(contagem_entidades)
print("\n")

#print(type(article.sents))
sentences = [x for x in article.sents]
#print(sentences[2])

print(' ')
print('------- SENTENCAS DO TEXTO LONGO -------\n')
i=1
for x in sentences: 
    print("S"+str(i)+": "+str(x)) 
    i=i+1
    
print(' ')
print('------- APRESENTACAO GRAFICA DA NER da SENTENÇA#3 -------\n')    
displacy.render(nlp(str(sentences[2])), jupyter=True, style='ent')
# Out:
#
# ------- TEXTO LONGO -------
#
# Peter Strzok, the F.B.I. senior counterintelligence agent who disparaged President Trump in inflammatory
# text messages and helped oversee the Hillary Clinton email and Russia investigations, has been fired for violating
# bureau policies, Mr. Strzok’s lawyer said Monday. Mr. Trump and his allies seized on the texts, exchanged during
# the 2016 campaign with a former F.B.I. lawyer, Lisa Page, in assailing the Russia investigation as an illegitimate 'witch hunt.'
# Mr. Strzok, who rose over 20 years at the F.B.I. to become one of its most experienced counterintelligence agents,
# was a key figure in the early months of the inquiry. Along with writing the texts, Mr. Strzok was accused of sending
# a highly sensitive search warrant to his personal email account. The F.B.I. had been under immense political pressure
# by Mr. Trump to dismiss Mr. Strzok, who was removed last summer from the staff of the special counsel, Robert S. Mueller III.
# The president has repeatedly denounced Mr. Strzok in posts on Twitter, and on Monday expressed satisfaction that he had been sacked.
#
#
# No. Entidades= 25
#
#
#
# ------- Contagem de Entidades por LABEL -------
#
# Counter({'PERSON': 12, 'DATE': 6, 'ORG': 4, 'GPE': 3})
#
#
#
# ------- TOP 3 Entidades -------
#
# [('Strzok', 5), ('F.B.I.', 4), ('Trump', 3)]
#
#
#
# ------- SENTENCAS DO TEXTO LONGO -------
#
# S1: Peter Strzok, the F.B.I. senior counterintelligence agent who disparaged President Trump in inflammatory
# text messages and helped oversee the Hillary Clinton email and Russia investigations, has been fired for violating
# bureau policies, Mr. Strzok’s lawyer said Monday.
# S2: Mr. Trump and his allies seized on the texts, exchanged during
# the 2016 campaign with a former F.B.I. lawyer, Lisa Page, in assailing the Russia investigation as an illegitimate 'witch hunt.'
#
# S3: Mr. Strzok, who rose over 20 years at the F.B.I. to become one of its most experienced counterintelligence agents,
# was a key figure in the early months of the inquiry.
# S4: Along with writing the texts, Mr. Strzok was accused of sending
# a highly sensitive search warrant to his personal email account.
# S5: The F.B.I. had been under immense political pressure
# by Mr. Trump to dismiss Mr. Strzok, who was removed last summer from the staff of the special counsel, Robert S. Mueller III.
#
# S6: The president has repeatedly denounced Mr. Strzok in posts on Twitter, and on Monday expressed satisfaction that he had been sacked.
#
# ------- APRESENTACAO GRAFICA DA NER da SENTENÇA#3 -------
# <div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who rose over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     20 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to become one of its most experienced counterintelligence agents,</br>was a key figure in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the early months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the inquiry.</div>

# %% [markdown]
# ## 2.3 Análise de Dependência Sintática com SpaCy

# %%
print(' ')
print('------- APRESENTACAO GRAFICA DA ANALISE DE DEPENDENCIA da SENTENÇA#3 -------\n')  
displacy.render(nlp(str(sentences[2])), style='dep', jupyter = True, options = {'distance': 180})
# Out:
#
# ------- APRESENTACAO GRAFICA DA ANALISE DE DEPENDENCIA da SENTENÇA#3 -------
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="de75647ad4f44c21bac51cd1daf66818-0" class="displacy" width="5630" height="767.0" direction="ltr" style="max-width: none; height: 767.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Strzok,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">rose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">20</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">F.B.I.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">become</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">experienced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3110">counterintelligence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3110">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">agents,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3470">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3470">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4010">key</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4190">figure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4190">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4370">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4730">early</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4910">months</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4910">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="5090">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="5270">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="5450">inquiry.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5450">NOUN</tspan>
# </text>
#
# <g class="

# %%
sentence2 = "John gave her his book"
#sentence1 = "João deu à ela seu livro."
sentence1 = "He saw the Eiffel Tower flying to Paris"
#sentence1 = "She borrowed a book from the library"

print(' ')
print('------- APRESENTACAO GRAFICA DA NER da SENTENÇA -------\n')    
displacy.render(nlp(str(sentence1)), jupyter=True, style='ent')

print(' ')
print('------- APRESENTACAO GRAFICA DA ANALISE DE DEPENDENCIA da SENTENÇA -------\n')  
displacy.render(nlp(str(sentence1)), style='dep', jupyter = True, options = {'distance': 120})

print(' ')
print('------- APRESENTACAO GRAFICA DA ANALISE DE DEPENDENCIA da SENTENÇA -------\n')  
displacy.render(nlp(str(sentence2)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
#
# ------- APRESENTACAO GRAFICA DA NER da SENTENÇA -------
# <div class="entities" style="line-height: 2.5; direction: ltr">He saw
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Eiffel Tower
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  flying to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
#
# ------- APRESENTACAO GRAFICA DA ANALISE DE DEPENDENCIA da SENTENÇA -------
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a9ba2791843d4281bc58801c8603b4cd-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Eiffel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Tower</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">flying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Paris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-1" stroke-width="2px" d="M310,182.0 C310,62.0 525.0,62.0 525.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-2" stroke-width="2px" d="M430,182.0 C430,122.0 520.0,122.0 520.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-4" stroke-width="2px" d="M190,182.0 C190,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-5" stroke-width="2px" d="M670,182.0 C670,122.0 760.0,122.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M760.0,184.0 L768.0,172.0 752.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba2791843d4281bc58801c8603b4cd-0-6" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba2791843d4281bc58801c8603b4cd-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,184.0 L888.0,172.0 872.0,172.0" fill="currentColor"/>
# </g>
# </svg>
#
# ------- APRESENTACAO GRAFICA DA ANALISE DE DEPENDENCIA da SENTENÇA -------
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="854900a14b1146f4bb817fa608471eb1-0" class="displacy" width="650" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">gave</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">book</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-854900a14b1146f4bb817fa608471eb1-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-854900a14b1146f4bb817fa608471eb1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-854900a14b1146f4bb817fa608471eb1-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-854900a14b1146f4bb817fa608471eb1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dative</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M285.0,124.0 L293.0,112.0 277.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-854900a14b1146f4bb817fa608471eb1-0-2" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-854900a14b1146f4bb817fa608471eb1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-854900a14b1146f4bb817fa608471eb1-0-3" stroke-width="2px" d="M190,122.0 C190,2.0 530.0,2.0 530.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-854900a14b1146f4bb817fa608471eb1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,124.0 L538.0,112.0 522.0,112.0" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# ### Material Auxiliar
#
# https://www.geeksforgeeks.org/nlp-chunking-rules/?ref=rp
# https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
